# %% [markdown]
# <h1>Opções B3 CALL's and PUT's</h1>
# 'VALE3','PETR4','ITUB4','BBDC4','B3SA3','BBAS3'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import math

listaAcoes = [
    'VALE3','PETR4'
]
linkAcoes = [
    'https://br.advfn.com/bolsa-de-valores/bovespa/vale-on-VALE3/cotacao',
    'https://br.advfn.com/bolsa-de-valores/bovespa/petrobras-pn-PETR4/cotacao'
]
max3meses = []
min3meses = []

sleep = 0

listaTipo = ['CALL','PUT']

Performance = []
Cotação = []
DataVencimento = []
volFinanceiro = []
investimentoMin = []
Opções = []
diferencaDatas = []
Strike = []
Tipo = []
volatImplicita = []
Ticker = []
PrecoAtual = []
TaxaDiaria = []
distPreco = []
potencialValorizacao = []

Análise = {
    'Tipo' : Tipo,
    'Opção' : Opções,
    'Strike' : Strike,
    'Vencimento' : DataVencimento,
    'Cotação' : Cotação,
    'Potencial' : potencialValorizacao,
    'Distância do Strike' : distPreco,
    'Taxa p/ Strike' : TaxaDiaria,
    'Performance' : Performance
}

# %%
def historico3meses(link):
    import requests

    cookies = {
        'ADVFNUID': 'bb82172f9b729adc27ec421e4d35c8acceba446',
        #'recent_stocks': 'BOV%5EVALE3',
        '_ga': 'GA1.1.442086764.1683113344',
        '_pbjs_userid_consent_data': '3524755945110770',
        '__gads': 'ID=b9974ffadeb678ac:T=1683113343:S=ALNI_MYlQg6kudTCeQ9f85ajt5lrozTXfg',
        '__gpi': 'UID=000009f26498bf53:T=1683113343:RT=1683113343:S=ALNI_MZ0BW5jzo_Rv5HDmxtVTfRBtivFTQ',
        '_ga_4ZDGEZ04EZ': 'GS1.1.1683113344.1.0.1683113347.0.0.0',
    }

    headers = {
        'authority': 'br.advfn.com',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
        'cache-control': 'max-age=0',
        # 'cookie': 'ADVFNUID=bb82172f9b729adc27ec421e4d35c8acceba446; recent_stocks=BOV%5EVALE3; _ga=GA1.1.442086764.1683113344; _pbjs_userid_consent_data=3524755945110770; __gads=ID=b9974ffadeb678ac:T=1683113343:S=ALNI_MYlQg6kudTCeQ9f85ajt5lrozTXfg; __gpi=UID=000009f26498bf53:T=1683113343:RT=1683113343:S=ALNI_MZ0BW5jzo_Rv5HDmxtVTfRBtivFTQ; _ga_4ZDGEZ04EZ=GS1.1.1683113344.1.0.1683113347.0.0.0',
        'dnt': '1',
        'referer': 'https://www.google.com/',
        'sec-ch-ua': '"Chromium";v="112", "Google Chrome";v="112", "Not:A-Brand";v="99"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'document',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-site': 'cross-site',
        'sec-fetch-user': '?1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36',
    }

    response = requests.get(link, cookies=cookies, headers=headers)
    from bs4 import BeautifulSoup
    response = BeautifulSoup(response.text,'html.parser')
    tabela = response.find_all('table' , attrs={'id' : 'id_period_quote'})
    #máxima em 3 meses
    print(tabela[0].find_all('tr')[3].find_all('td')[2])
    #mínima em 3 meses
    print(tabela[0].find_all('tr')[3].find_all('td')[3])

# %%
def cotacaoACAO(acao):#Retorna cotação atual da ação
    time.sleep(sleep)
    cookies = {
        'OTZ': '6926103_68_64_73560_68_416340',
        'SID': 'TwhdIz4Q1SP3B7J-km2f-xaiq3HWwc9dU6A3nFHEUpqIav1Ex7pSlCAwXQHz-42o_CKXlg.',
        '__Secure-1PSID': 'TwhdIz4Q1SP3B7J-km2f-xaiq3HWwc9dU6A3nFHEUpqIav1EKjEtrapbbOiqszjABPXyyw.',
        '__Secure-3PSID': 'TwhdIz4Q1SP3B7J-km2f-xaiq3HWwc9dU6A3nFHEUpqIav1Eh6u-6u1bwmD0ksSvfItSEA.',
        'HSID': 'A4pN5chHxcB5md1Uv',
        'APISID': 'oVJMj7LxIv5AELVo/AER5Ey5IdMuBWa0yK',
        'SSID': 'AP0JJP5nP-3zWKh9p',
        'SAPISID': 'JUZiPVNORqSNzLd0/AUqc6WV_MWv0d4Bxp',
        '__Secure-1PAPISID': 'JUZiPVNORqSNzLd0/AUqc6WV_MWv0d4Bxp',
        '__Secure-3PAPISID': 'JUZiPVNORqSNzLd0/AUqc6WV_MWv0d4Bxp',
        'SEARCH_SAMESITE': 'CgQI5pcB',
        'NID': '511=FFqtFrNqBCOEVESzU-OY2lMVWBPY07sY61s2vGiEVhE4Zy-2iyXrVzZ1Qw365CbMaI45DUoYvtKxywPClk6e7xFURlv5fNBbGTbuKzVGLZDykTgwA2g1UEN6icW4uZOfxoMlqTen3-hPNJUTwbzIKx5osU6BDbno2ABUhNxaGi15CWjnVNQUwj62TKCeMd5xKcjMmZQHHC_leD6r9H2hYmQCN_weOOmQWcJ__yLK4vvqzf2FGHEDPDartui8XeWPkTNyrXc7XpQow01a_pBD-u4uI92Vz_0BeqkMUPgZgKIz',
        'AEC': 'ARSKqsI8F_x5mffL__ZKO0lj5XxwKOPuo8hEOjPQzxWUIFTTbo8FCdHt-Q',
        'DV': 'o3HrtBnbFdJfsEu3TBqN0bcVb5BbblhuvY3uL0GCogAAAJBY25rkkIreSAAAAAhSt0bRcateRwAAAOrXM7IaFq81EgAAAA',
        '1P_JAR': '2023-03-15-14',
        'SIDCC': 'AFvIBn8Pi0i6CShe05qgeWDNZgKpjH6hSK_dQJl13IXolIfVxBuFuKzYn3iVw8gd8Ow4XUSIJc4Z',
        '__Secure-1PSIDCC': 'AFvIBn__JzDmmwuGH9dzgBkpHkNm147X1Io4mcISKCNbqAW-2Gc1rXE2cONhk62X3LId9kWENJ9p',
        '__Secure-3PSIDCC': 'AFvIBn_zom19_H1EBdMKvfjwPLYr998ephop5YwPzfDX962AvBaITYUIaPWCke9UTxmLfm1HJlql',
    }

    headers = {
        'authority': 'www.google.com',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
        'cache-control': 'max-age=0',
        # 'cookie': 'OTZ=6926103_68_64_73560_68_416340; SID=TwhdIz4Q1SP3B7J-km2f-xaiq3HWwc9dU6A3nFHEUpqIav1Ex7pSlCAwXQHz-42o_CKXlg.; __Secure-1PSID=TwhdIz4Q1SP3B7J-km2f-xaiq3HWwc9dU6A3nFHEUpqIav1EKjEtrapbbOiqszjABPXyyw.; __Secure-3PSID=TwhdIz4Q1SP3B7J-km2f-xaiq3HWwc9dU6A3nFHEUpqIav1Eh6u-6u1bwmD0ksSvfItSEA.; HSID=A4pN5chHxcB5md1Uv; APISID=oVJMj7LxIv5AELVo/AER5Ey5IdMuBWa0yK; SSID=AP0JJP5nP-3zWKh9p; SAPISID=JUZiPVNORqSNzLd0/AUqc6WV_MWv0d4Bxp; __Secure-1PAPISID=JUZiPVNORqSNzLd0/AUqc6WV_MWv0d4Bxp; __Secure-3PAPISID=JUZiPVNORqSNzLd0/AUqc6WV_MWv0d4Bxp; SEARCH_SAMESITE=CgQI5pcB; NID=511=FFqtFrNqBCOEVESzU-OY2lMVWBPY07sY61s2vGiEVhE4Zy-2iyXrVzZ1Qw365CbMaI45DUoYvtKxywPClk6e7xFURlv5fNBbGTbuKzVGLZDykTgwA2g1UEN6icW4uZOfxoMlqTen3-hPNJUTwbzIKx5osU6BDbno2ABUhNxaGi15CWjnVNQUwj62TKCeMd5xKcjMmZQHHC_leD6r9H2hYmQCN_weOOmQWcJ__yLK4vvqzf2FGHEDPDartui8XeWPkTNyrXc7XpQow01a_pBD-u4uI92Vz_0BeqkMUPgZgKIz; AEC=ARSKqsI8F_x5mffL__ZKO0lj5XxwKOPuo8hEOjPQzxWUIFTTbo8FCdHt-Q; DV=o3HrtBnbFdJfsEu3TBqN0bcVb5BbblhuvY3uL0GCogAAAJBY25rkkIreSAAAAAhSt0bRcateRwAAAOrXM7IaFq81EgAAAA; 1P_JAR=2023-03-15-14; SIDCC=AFvIBn8Pi0i6CShe05qgeWDNZgKpjH6hSK_dQJl13IXolIfVxBuFuKzYn3iVw8gd8Ow4XUSIJc4Z; __Secure-1PSIDCC=AFvIBn__JzDmmwuGH9dzgBkpHkNm147X1Io4mcISKCNbqAW-2Gc1rXE2cONhk62X3LId9kWENJ9p; __Secure-3PSIDCC=AFvIBn_zom19_H1EBdMKvfjwPLYr998ephop5YwPzfDX962AvBaITYUIaPWCke9UTxmLfm1HJlql',
        'dnt': '1',
        'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
        'sec-ch-ua-arch': '"x86"',
        'sec-ch-ua-bitness': '"64"',
        'sec-ch-ua-full-version': '"111.0.5563.65"',
        'sec-ch-ua-full-version-list': '"Google Chrome";v="111.0.5563.65", "Not(A:Brand";v="8.0.0.0", "Chromium";v="111.0.5563.65"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-model': '""',
        'sec-ch-ua-platform': '"Windows"',
        'sec-ch-ua-platform-version': '"10.0.0"',
        'sec-ch-ua-wow64': '?0',
        'sec-fetch-dest': 'document',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-user': '?1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36',
        'x-client-data': 'CIa2yQEIorbJAQjEtskBCKmdygEIh/PKAQiTocsBCOeyzAEImvbMAQiJjM0BCLWUzQEIiZbNAQiols0BCOKXzQEI45fNAQjMmM0BCLmZzQEI85nNAQi1ms0BCK6ErQI=',
    }

    params = {
        'q': acao,
    }

    response = requests.get('https://www.google.com/search', params=params, cookies=cookies, headers=headers)
    #print('Cotação Atual response =',response)
    cotacao = BeautifulSoup(response.text,'html.parser').find_all('span', attrs={'jsname' : 'vWLAgc'})
    cotacao = float(cotacao[0].text.replace(',','.'))
    return cotacao

# %%
def matrizOpcoesPut(acao):#Função que retorna a tabela matriz de opções - todas as tr e td
    time.sleep(sleep)
    cookies = {
        '_gid': 'GA1.3.1918614292.1678804241',
        '.AspNetCore.Antiforgery.g1ir8UL7PVw': 'CfDJ8HsBx5QvkSVDi0StK1p8kcMltQjMqS0MkuXG_kGFu7OsajMMfx0S2EnCyVT29kBzkkHkWTyEdBF46dhHqwcjllvkX-xLq3tTGvzDL7asbvpt4boq6_XRNzYrwE8ZpfxfryoueM52At1EyH6eDNj5CCI',
        '_ga_YH2ELJFQPC': 'GS1.1.1678888561.2.1.1678890416.0.0.0',
        '_ga': 'GA1.3.1970705556.1678804241',
    }

    headers = {
        'authority': 'opcoes.net.br',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
        'cache-control': 'max-age=0',
        # 'cookie': '_gid=GA1.3.1918614292.1678804241; .AspNetCore.Antiforgery.g1ir8UL7PVw=CfDJ8HsBx5QvkSVDi0StK1p8kcMltQjMqS0MkuXG_kGFu7OsajMMfx0S2EnCyVT29kBzkkHkWTyEdBF46dhHqwcjllvkX-xLq3tTGvzDL7asbvpt4boq6_XRNzYrwE8ZpfxfryoueM52At1EyH6eDNj5CCI; _ga_YH2ELJFQPC=GS1.1.1678888561.2.1.1678890416.0.0.0; _ga=GA1.3.1970705556.1678804241',
        'dnt': '1',
        'referer': 'https://opcoes.net.br/matriz-opcoes-strike-x-vencimento/PUTs/'+ acao,
        'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'document',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-user': '?1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36',
    }

    response = requests.get(
        'https://opcoes.net.br/matriz-opcoes-strike-x-vencimento/PUTs/' + acao + '/negociadas-nos-ultimos-7-dias/ou-com-FM',
        cookies=cookies,
        headers=headers,
    )
    #print('Response da Matriz PUT =',response)
    pagina = BeautifulSoup(response.text,'html.parser').find_all('table', attrs={'class' : 'table table-bordered table-condensed'})

    return pagina[0]

# %%
def matrizOpcoesCall(acao):#Função que retorna a tabela matriz de opções - todas as tr e td
    time.sleep(sleep)
    cookies = {
        '_gid': 'GA1.3.1918614292.1678804241',
        '.AspNetCore.Antiforgery.g1ir8UL7PVw': 'CfDJ8HsBx5QvkSVDi0StK1p8kcMltQjMqS0MkuXG_kGFu7OsajMMfx0S2EnCyVT29kBzkkHkWTyEdBF46dhHqwcjllvkX-xLq3tTGvzDL7asbvpt4boq6_XRNzYrwE8ZpfxfryoueM52At1EyH6eDNj5CCI',
        '_ga_YH2ELJFQPC': 'GS1.1.1678888561.2.1.1678890416.0.0.0',
        '_ga': 'GA1.3.1970705556.1678804241',
    }

    headers = {
        'authority': 'opcoes.net.br',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
        'cache-control': 'max-age=0',
        # 'cookie': '_gid=GA1.3.1918614292.1678804241; .AspNetCore.Antiforgery.g1ir8UL7PVw=CfDJ8HsBx5QvkSVDi0StK1p8kcMltQjMqS0MkuXG_kGFu7OsajMMfx0S2EnCyVT29kBzkkHkWTyEdBF46dhHqwcjllvkX-xLq3tTGvzDL7asbvpt4boq6_XRNzYrwE8ZpfxfryoueM52At1EyH6eDNj5CCI; _ga_YH2ELJFQPC=GS1.1.1678888561.2.1.1678890416.0.0.0; _ga=GA1.3.1970705556.1678804241',
        'dnt': '1',
        'referer': 'https://opcoes.net.br/matriz-opcoes-strike-x-vencimento/CALLs/'+acao,
        'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'document',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-user': '?1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36',
    }

    response = requests.get(
        'https://opcoes.net.br/matriz-opcoes-strike-x-vencimento/CALLs/' + acao + '/negociadas-nos-ultimos-7-dias/ou-com-FM',
        cookies=cookies,
        headers=headers,
    )
    #print('Response da Matriz CALL =',response)
    pagina = BeautifulSoup(response.text,'html.parser').find_all('table', attrs={'class' : 'table table-bordered table-condensed'})

    return pagina[0]

# %%
def extraiSiglasPut(acao):#Retorna lista com as siglas das opcoes
    #print('Extraindo siglas PUT da ação',acao)
    time.sleep(sleep)
    tabela = matrizOpcoesPut(acao)
    cotacaoAtual = cotacaoACAO(acao) #recebe valor em float

    for linha in range(1,len(tabela.find_all('tr'))):
        strikeOpcao = tabela.find_all('tr')[linha].find_all('td')[0].text
        strikeOpcao = float(strikeOpcao.replace(',','.'))
        if strikeOpcao < cotacaoAtual: 
            for coluna in range(1,4):
                try:
                    dado = tabela.find_all('tr')[linha].find_all('td')[coluna].find_all('a')[0].text
                    dado = dado.strip()
                    if dado.startswith(acao[0:4]):
                        Opções.append(dado)
                        Strike.append(strikeOpcao)
                        Tipo.append('PUT')
                        Ticker.append(acao)
                        Performance.append(0)
                        Cotação.append(0)
                        DataVencimento.append('')
                        volFinanceiro.append(0)
                        investimentoMin.append(0)
                        diferencaDatas.append(0)
                        volatImplicita.append(0)
                        TaxaDiaria.append(0)
                        distPreco.append(0)
                        potencialValorizacao.append(0)
                        PrecoAtual.append(cotacaoAtual)
                except:
                    pass

# %%
def extraiSiglasCall(acao):#Retorna lista com as siglas das opcoes
    #print('Extraindo siglas CALL da ação',acao)
    time.sleep(sleep)
    tabela = matrizOpcoesCall(acao)
    cotacaoAtual = cotacaoACAO(acao) #recebe valor em float

    for linha in range(1,len(tabela.find_all('tr'))):
        strikeOpcao = tabela.find_all('tr')[linha].find_all('td')[0].text
        strikeOpcao = float(strikeOpcao.replace(',','.'))
        if strikeOpcao > cotacaoAtual: 
            for coluna in range(1,4):
                try:
                    dado = tabela.find_all('tr')[linha].find_all('td')[coluna].find_all('a')[0].text
                    dado = dado.strip()
                    if dado.startswith(acao[0:4]):
                        Opções.append(dado)
                        Strike.append(strikeOpcao)
                        Tipo.append('CALL')                        
                        Ticker.append(acao)
                        Performance.append(0)
                        Cotação.append(0)
                        DataVencimento.append('')
                        volFinanceiro.append(0)
                        investimentoMin.append(0)
                        diferencaDatas.append(0)
                        volatImplicita.append(0)
                        TaxaDiaria.append(0)
                        distPreco.append(0)
                        potencialValorizacao.append(0)
                        PrecoAtual.append(cotacaoAtual)
                except:
                    pass

# %%
def extraiDadosOpcao(opcao):  # Apenda cotacao e vencimento de cada opcao
    #print('Extraindo dados de:',opcao)
    import time
    time.sleep(sleep)
    index = Opções.index(opcao)
    try:
        response = requests.get('https://opcoes.net.br/' + opcao)
        pagina = BeautifulSoup(response.text, 'html.parser')

        # Cotação = []
        cotacao = pagina.find_all('table', attrs={'class': 'table table-bordered table-condensed top-buffer-20'})[0].find_all('tr')[2].find_all('td')[4].text
        cotacao = float(cotacao.replace(',', '.'))
    except:
        cotacao = float(0)
    Cotação[index] = cotacao

    # investimentoMin = []
    investMin = float(cotacao*100)
    investimentoMin[index] = investMin

    try:
        # DataVencimento = []
        vencimento = pagina.find_all(
            'div', attrs={'class': 'col-md-12'})[0].find_all('h1')[0].text
        vencimento = vencimento[-10:]
        DataVencimento[index] = vencimento
    except:
        vencimento = '31/12/9999'

    try:
        # volFinanceiro = []
        volFin = pagina.find_all('table', attrs={
                                    'class': 'table table-bordered table-condensed top-buffer-20'})[0].find_all('tr')[2].find_all('td')[6].text
        volFin = volFin.replace('.', '').replace(',', '.')
    except:
        volFin = 0
    volFinanceiro[index] = float(volFin)
    try:
        volatImpl = pagina.find_all('table', attrs={'class' : 'table table-bordered table-condensed top-buffer-20'})[0].find_all('tr')[2].find_all('td')[11].text.replace('.', '').replace(',', '.')
        volatImplicita[index] = float(volatImpl)
    except:
        volatImplicita[index] = 0

# %%
def diferencaEmDias(opcao):#Retorna lista de diferença entre duas datas em dias
    #print(opcao)
    from networkdays import networkdays
    import datetime    
    index = Opções.index(opcao)
    try:
        delta = networkdays.Networkdays(datetime.date(datetime.datetime.now().year,
                                        datetime.datetime.now().month,
                                        datetime.datetime.now().day),
                                        datetime.date(int(DataVencimento[index][6:10]),
                                        int(DataVencimento[index][3:5]),
                                        int(DataVencimento[index][0:2]))
        )
        diferencaDatas[index] = len(delta.networkdays())
        #print('A opção',opcao,'vence em',diferencaDatas[index],'dias')
    except:
        diferencaDatas[index] = 0

# %%
def calculaPerformance(opcao):
    try:
        #time.sleep(0.5)
        index = Opções.index(opcao)
        cotacaoAtual = PrecoAtual[index]
        acao = Ticker[index]
        tipo = Tipo[index]
        tabelaOpcoes = pd.DataFrame(Análise)

        taxa = round(abs(math.pow((Strike[index]/cotacaoAtual),(1/diferencaDatas[index]))-1)*100,2)
        TaxaDiaria[index] = taxa

        distancia = round((Strike[index]/PrecoAtual[index]-1)*100,2)
        distPreco[index] = distancia
        
        cotacaoMax = tabelaOpcoes['Cotação'].loc[tabelaOpcoes['Opção'].str.contains(acao[0:4],case=True)].loc[tabelaOpcoes['Tipo'] == tipo].max()
        potencial = round(abs(cotacaoMax/Cotação[index]),2)
        potencialValorizacao[index] = potencial

        performance = volFinanceiro[index]/TaxaDiaria[index]
        Performance[index] = performance

        #print('Performance da',opcao,'calculada com sucesso')
    except:
        Performance[index] = 0
        #print('Erro ao calcular a performance da',opcao)

# %%
def main():
    for acao in listaAcoes:
        extraiSiglasPut(acao)
        extraiSiglasCall(acao)
    for opcao in Opções:
        extraiDadosOpcao(opcao)
        diferencaEmDias(opcao)
        calculaPerformance(opcao)

# %%
main()

# %%
tabelaOpcoes = pd.DataFrame(Análise)

minimo = 1
exibicao = 10

for acao in listaAcoes:
        for tipo in listaTipo:
                view = tabelaOpcoes.loc[tabelaOpcoes['Cotação']<=0.66].loc[tabelaOpcoes['Potencial'] >=2 ].loc[tabelaOpcoes['Opção'].str.contains(acao[0:4],case=True)].loc[tabelaOpcoes['Tipo'] == tipo].loc[tabelaOpcoes['Distância do Strike'].between(-10,10)].sort_values(by=['Taxa p/ Strike'], ascending=True).head(exibicao)
                cotacaoMax = view['Cotação'].max()    

                print(acao, cotacaoACAO(acao))
                print("Opções",tipo,"de",acao,'\ntem a cotação de mais alta de R$',cotacaoMax)
                display(view)
# Out:
# VALE3 65.83
# Opções CALL de VALE3
# tem a cotação de mais alta de R$ 0.61
#      Tipo     Opção  Strike  Vencimento  Cotação  Potencial  \
# 124  CALL  VALEF711   71.16  16/06/2023     0.61       7.69
# 127  CALL  VALEF716   71.66  16/06/2023     0.60       7.82
# 130  CALL  VALEF721   72.16  16/06/2023     0.42      11.17
#
#      Distância do Strike  Taxa p/ Strike  Performance
# 124                 8.10            0.52  1403.846154
# 127                 8.86            0.57  1077.192982
# 130                 9.62            0.61   767.213115
# VALE3 65.83
# Opções PUT de VALE3
# tem a cotação de mais alta de R$ 0.61
#    Tipo     Opção  Strike  Vencimento  Cotação  Potencial  \
# 72  PUT  VALER621   62.16  16/06/2023     0.61       3.43
# 69  PUT  VALER616   61.66  16/06/2023     0.55       3.13
# 66  PUT  VALER611   61.16  16/06/2023     0.41       4.20
# 63  PUT  VALER606   60.66  16/06/2023     0.41       4.20
# 60  PUT  VALER601   60.16  16/06/2023     0.35       4.43
# 57  PUT  VALER596   59.66  16/06/2023     0.31       4.55
#
#     Distância do Strike  Taxa p/ Strike  Performance
# 72                -5.57            0.38   610.526316
# 69                -6.33            0.44   531.818182
# 66                -7.09            0.49   857.142857
# 63                -7.85            0.54   738.888889
# 60                -8.61            0.60   806.666667
# 57                -9.37            0.65   710.769231
# PETR4 26.69
# Opções CALL de PETR4
# tem a cotação de mais alta de R$ 0.66
#      Tipo     Opção  Strike  Vencimento  Cotação  Potencial  \
# 412  CALL  PETRF281   27.22  16/06/2023     0.58       3.14
# 429  CALL  PETRG294   28.58  21/07/2023     0.66       2.76
# 415  CALL  PETRF288   27.47  16/06/2023     0.48       3.79
# 431  CALL  PETRG316   28.83  21/07/2023     0.57       3.19
# 433  CALL  PETRG351   29.08  21/07/2023     0.52       3.50
# 436  CALL  PETRG304   29.33  21/07/2023     0.44       4.14
# 418  CALL  PETRF264   27.72  16/06/2023     0.39       4.67
# 421  CALL  PETRF473   27.97  16/06/2023     0.32       5.69
# 424  CALL  PETRF301   28.22  16/06/2023     0.27       6.74
# 427  CALL  PETRF299   28.47  16/06/2023     0.20       9.10
#
#      Distância do Strike  Taxa p/ Strike   Performance
# 412                 1.99            0.13  26884.615385
# 429                 7.08            0.17   1335.294118
# 415                 2.92            0.19  15884.210526
# 431                 8.02            0.19     63.157895
# 433                 8.95            0.21    204.761905
# 436                 9.89            0.24    204.166667
# 418                 3.86            0.25   5864.000000
# 421                 4.80            0.31   1854.838710
# 424                 5.73            0.37    791.891892
# 427                 6.67            0.43   1690.697674
# PETR4 26.69
# Opções PUT de PETR4
# tem a cotação de mais alta de R$ 0.46
#     Tipo     Opção  Strike  Vencimento  Cotação  Potencial  \
# 400  PUT  PETRR273   26.22  16/06/2023     0.46       2.00
# 397  PUT  PETRR500   25.97  16/06/2023     0.38       2.26
# 394  PUT  PETRR259   25.72  16/06/2023     0.33       2.61
# 391  PUT  PETRR258   25.47  16/06/2023     0.27       3.19
# 388  PUT  PETRR279   25.22  16/06/2023     0.23       2.87
# 385  PUT  PETRR443   24.97  16/06/2023     0.20       2.95
# 382  PUT  PETRR251   24.72  16/06/2023     0.16       3.25
# 379  PUT  PETRR248   24.47  16/06/2023     0.13       4.00
# 376  PUT  PETRR303   24.22  16/06/2023     0.12       4.33
#
#      Distância do Strike  Taxa p/ Strike   Performance
# 400                -1.76            0.12  24866.666667
# 397                -2.70            0.18  13666.666667
# 394                -3.63            0.25  27940.000000
# 391                -4.57            0.31   8574.193548
# 388                -5.51            0.38   1002.631579
# 385                -6.44            0.44   1120.454545
# 382                -7.38            0.51   1772.549020
# 379                -8.32            0.58   3817.241379
# 376                -9.25            0.65   4393.846154
